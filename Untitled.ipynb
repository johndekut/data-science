# %% [markdown]
# ##for loops

# %%
#range objects
my_range = range(0, 5)
print(my_range)
print(list(my_range))
# Out:
# range(0, 5)
# [0, 1, 2, 3, 4]

# %%
my_list=[1, 2, 3, 4,5 ,6 ,7, 9]
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 9]
